# %% [markdown]
# ## Exercici 4 - Tasca 6: Visualització gràfica d'un dataset - Eduardo Baffi
# ### Integra les visualitzacions gràfiques, en la tasca 5, del Sprint 3.

# %% [markdown]
# ## Tasca 5, del Sprint 3 + gràfiques
# ### Exercici 1

# %%
# - Exercici 1
# Descarrega el data set Airlines Delay: Airline on-time statistics and delay causes i carrega’l a un pandas Dataframe. 
# Explora les dades que conté, i queda’t únicament amb les columnes que consideris rellevants.

import pandas as pd

airlines_df = pd.read_csv('DelayedFlights.csv')
pd.options.display.max_columns = None           #Ver todas las columnas
airlines_df[:3]
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
#
#    ArrTime  CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0   2211.0        2225            WN        335  N712SW              128.0
# 1   1002.0        1000            WN       3231  N772SW              128.0
# 2    804.0         750            WN        448  N428WN               96.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# 0           150.0    116.0     -14.0       8.0    IAD  TPA       810     4.0
# 1           145.0    113.0       2.0      19.0    IAD  TPA       810     5.0
# 2            90.0     76.0      14.0       8.0    IND  BWI       515     3.0
#
# ...

# %% [markdown]
# ### Variable descriptions
# (available here: http://stat-computing.org/dataexpo/2009/the-data.html)
#
#     Name	             Description
# 1	Year	             1987-2008
# 2	Month	             1-12
# 3	DayofMonth	         1-31
# 4	DayOfWeek	         1 (Monday) - 7 (Sunday)
# 5	DepTime	actual       departure time (local, hhmm)
# 6	CRSDepTime	         scheduled departure time (local, hhmm)
# 7	ArrTime	             actual arrival time (local, hhmm)
# 8	CRSArrTime	         scheduled arrival time (local, hhmm)
# 9	UniqueCarrier	     unique carrier code
# 10	FlightNum	         flight number
# 11	TailNum	plane        tail number
# 12	ActualElapsedTime	 in minutes
# 13	CRSElapsedTime	     in minutes
# 14	AirTime	             in minutes
# 15	ArrDelay	         arrival delay, in minutes
# 16	DepDelay	         departure delay, in minutes
# 17	Origin	             origin IATA airport code
# 18	Dest	             destination IATA airport code
# 19	Distance	         in miles
# 20	TaxiIn	taxi         in time, in minutes
# 21	TaxiOut	taxi         out time in minutes
# 22	Cancelled	         was the flight cancelled?
# 23	CancellationCode	 reason for cancellation (A = carrier, B = weather, C = NAS, D = security)
# 24	Diverted	         1 = yes, 0 = no
# 25	CarrierDelay	     in minutes
# 26	WeatherDelay	     in minutes
# 27	NASDelay	         in minutes
# 28	SecurityDelay	     in minutes
# 29	LateAircraftDelay	 in minutes
#
# * Descripción de las columnas del dataset

# %%
airlines_df
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
somecolum = airlines_df[['CancellationCode','CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']]
somecolum
# Out:
#         CancellationCode  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0                      N           NaN           NaN       NaN            NaN
# 1                      N           NaN           NaN       NaN            NaN
# 2                      N           NaN           NaN       NaN            NaN
# 3                      N           2.0           0.0       0.0            0.0
# 4                      N           NaN           NaN       NaN            NaN
# ...                  ...           ...           ...       ...            ...
# 1936753                N           3.0           0.0       0.0            0.0
# 1936754                N           0.0          57.0      18.0            0.0
# 1936755                N           1.0           0.0      19.0            0.0
# 1936756                N           NaN           NaN       NaN            NaN
# 1936757                N           NaN           NaN       NaN            NaN
#
#          LateAircraftDelay
# ...

# %%
airlines_df['Year'].value_counts()
# Out:
# 2008    1936758
# Name: Year, dtype: int64

# %%
airlines_df['Origin'].value_counts()
# Out:
# ATL    131613
# ORD    125979
# DFW     95414
# DEN     74323
# LAX     58772
#         ...
# BJI         4
# PIR         3
# PUB         2
# TUP         1
# INL         1
# Name: Origin, Length: 303, dtype: int64

# %%
airlines_df['Dest'].value_counts()
# Out:
# ORD    108984
# ATL    106898
# DFW     70657
# DEN     63003
# LAX     59969
#         ...
# INL         9
# PIR         3
# OGD         1
# CYS         1
# TUP         1
# Name: Dest, Length: 304, dtype: int64

# %%
Carrier_counts = airlines_df['UniqueCarrier'].value_counts()
Carrier_counts[:10]
Carrier_counts[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.kdeplot(Carrier_counts, shade=True)
plt.show()

# %%
airlines_df['Cancelled'].value_counts()
# Out:
# 0    1936125
# 1        633
# Name: Cancelled, dtype: int64

# %%
airlines_df['Diverted'].value_counts()
# Out:
# 0    1929004
# 1       7754
# Name: Diverted, dtype: int64

# %%
airlines_df['CarrierDelay'].value_counts()
# Out:
# 0.0      591049
# 6.0       22799
# 7.0       21500
# 15.0      20361
# 8.0       19506
#           ...
# 904.0         1
# 851.0         1
# 872.0         1
# 837.0         1
# 532.0         1
# Name: CarrierDelay, Length: 983, dtype: int64

# %%
airlines_df.isnull().sum()
# Out:
# Unnamed: 0                0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   5
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# TaxiIn                 7110
# TaxiOut                 455
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# dtype: int64

# %%
airlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   Year               int64
#  2   Month              int64
#  3   DayofMonth         int64
#  4   DayOfWeek          int64
#  5   DepTime            float64
#  6   CRSDepTime         int64
#  7   ArrTime            float64
#  8   CRSArrTime         int64
#  9   UniqueCarrier      object
#  10  FlightNum          int64
#  11  TailNum            object
#  12  ActualElapsedTime  float64
#  13  CRSElapsedTime     float64
#  14  AirTime            float64
#  15  ArrDelay           float64
#  16  DepDelay           float64
#  17  Origin             object
#  18  Dest               object
#  19  Distance           int64
#  20  TaxiIn             float64
#  21  TaxiOut            float64
#  22  Cancelled          int64
#  23  CancellationCode   object
# ...

# %%
airlines_df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
airlines_df['Month'].value_counts()
# Out:
# 12    203385
# 6     200914
# 3     200842
# 2     189534
# 1     183527
# 7     182945
# 8     162648
# 4     155264
# 5     153072
# 11    105563
# 10    103525
# 9      95539
# Name: Month, dtype: int64

# %%
# Después de explorar los datos, he generado un nuevo Dataframe únicamente con las columnas que consideres relevantes.
# Todos los vuelos son de 2008, entonces he sacado la columna del año
airlines_newdf= airlines_df.filter(['Month','DayofMonth','DayOfWeek','DepTime','CRSDepTime','ArrTime','CRSArrTime','UniqueCarrier','FlightNum','TailNum','ActualElapsedTime','CRSElapsedTime','AirTime','ArrDelay','DepDelay','Origin','Dest','Distance','Cancelled','CancellationCode','Diverted','CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay'], axis=1)
airlines_newdf   # Nuevo Dataframe
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0            1           3          4   2003.0        1955   2211.0
# 1            1           3          4    754.0         735   1002.0
# 2            1           3          4    628.0         620    804.0
# 3            1           3          4   1829.0        1755   1959.0
# 4            1           3          4   1940.0        1915   2121.0
# ...        ...         ...        ...      ...         ...      ...
# 1936753     12          13          6   1250.0        1220   1617.0
# 1936754     12          13          6    657.0         600    904.0
# 1936755     12          13          6   1007.0         847   1149.0
# 1936756     12          13          6   1251.0        1240   1446.0
# 1936757     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0              2225            WN        335  N712SW              128.0
# ...

# %% [markdown]
# ## Exercici 2

# %%
# - Exercici 2
# Fes un informe complet del data set:.

# Resumeix estadísticament les columnes d’interès
# Troba quantes dades faltants hi ha per columna
# Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...)
# Taula de les aerolínies amb més endarreriments acumulats
# Quins són els vols més llargs? I els més endarrerits? Etc.

# %% [markdown]
# #### Resumo estadístico de las columnas de interés

# %%
# Numero de vuelos en cada mes de 2008:
month_counts = airlines_newdf['Month'].value_counts()
total_flights = airlines_newdf.shape[0]
month_counts.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.displot(x=airlines_newdf['Month'], bins=12)

# %%
(month_counts/total_flights).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Dias con mas vuelos en Deciembre
december_counts = airlines_newdf['Month'] == 12
december_flights = airlines_newdf[december_counts]
december_flights['DayofMonth'].value_counts()
# Out:
# 22    10693
# 23    10621
# 1     10367
# 21     9994
# 19     9989
# 20     9249
# 27     9241
# 18     9066
# 17     8874
# 26     8707
# 24     8169
# 15     7382
# 28     7300
# 16     7069
# 30     5810
# 11     5661
# 10     5482
# 29     5327
# 31     5192
# 2      5184
# 12     5117
# 14     4999
# 25     4851
# 4      4293
# 7      4166
# 9      3944
# 3      3941
# 5      3726
# 8      3388
# 13     3009
# 6      2574
# Name: DayofMonth, dtype: int64

# %%
airlines_newdf['DayOfWeek'].value_counts()
# Out:
# 5    323259
# 1    290933
# 4    289451
# 7    286111
# 3    262805
# 2    260943
# 6    223256
# Name: DayOfWeek, dtype: int64

# %%
#Dias de la semana con mas vuelos en 2008
weekday_counts = airlines_newdf['DayOfWeek'].value_counts()
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts
# Out:
# Monday       323259
# Tuesday      290933
# Wednesday    289451
# Thursday     286111
# Friday       262805
# Saturday     260943
# Sunday       223256
# Name: DayOfWeek, dtype: int64

# %%
# Total de vuelos por aerolínea
carrier_counts = airlines_newdf['UniqueCarrier'].value_counts()
carrier_counts[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
carrier_counts[:10]
# Out:
# WN    377602
# AA    191865
# MQ    141920
# UA    141426
# OO    132433
# DL    114238
# XE    103663
# CO    100195
# US     98425
# EV     81877
# Name: UniqueCarrier, dtype: int64

# %%
plt.pie(carrier_counts[:10], labels=carrier_counts.index[:10], labeldistance=1.15);
plt.show();

# %%
# 10 aviones con mas vuelos en 2008 
tail_counts = airlines_newdf['TailNum'].value_counts()
tail_counts[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
tail_counts
# Out:
# N325SW    965
# N676SW    951
# N658SW    945
# N313SW    937
# N308SA    936
#          ...
# N74007      1
# 9609E       1
# N77006      1
# N27015      1
# N853NW      1
# Name: TailNum, Length: 5366, dtype: int64

# %%
sns.kdeplot(x=tail_counts[:10], shade=True, color="red")
plt.show()

# %%
# 20 aviones con menos vuelos en 2008 
tail_counts = airlines_newdf['TailNum'].value_counts()
tail_counts.tail(20)
# Out:
# N37018    2
# N77019    2
# 9189E     1
# N193UA    1
# 9149E     1
# N623US    1
# N859NW    1
# N194UA    1
# N77006    1
# N702DN    1
# N74007    1
# N78008    1
# N104UA    1
# N853NW    1
# N171DN    1
# N27015    1
# N76010    1
# N856NW    1
# 9609E     1
# N826MH    1
# Name: TailNum, dtype: int64

# %%
# Mayores retrasos en la llegada de los vuelos en minutos
arrival_values = airlines_newdf['ArrDelay']
arrival_values.nlargest(10)
# Out:
# 322516     2461.0
# 686014     2453.0
# 839306     1951.0
# 1009553    1707.0
# 1881639    1655.0
# 1497823    1583.0
# 685437     1542.0
# 163379     1525.0
# 1214839    1510.0
# 521096     1490.0
# Name: ArrDelay, dtype: float64

# %%
# Mayor retraso en la llegada de un vuelo de 2008
airlines_newdf.iloc[[322516]]
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 322516      2           3          7   1117.0        1820   2256.0
#
#         CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 322516         555            NW        808  N817NW              459.0
#
#         CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 322516           455.0    437.0    2461.0    2457.0    HNL  MSP      3972
#
#         Cancelled CancellationCode  Diverted  CarrierDelay  WeatherDelay  \
# 322516          0                N         0        1455.0           0.0
#
#         NASDelay  SecurityDelay  LateAircraftDelay
# 322516       4.0            0.0             1002.0

# %%
# Ciudades de las salidas
origin_counts = airlines_newdf['Origin'].value_counts()
origin_counts[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Destinos
dest_counts = airlines_newdf['Dest'].value_counts()
dest_counts[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Distancias (La primera columna es de laditacia del vuelo y la segunda el numero de veces que aparece en el dataframe)
airlines_newdf['Distance'].value_counts()
# Out:
# 337     13182
# 733      8720
# 761      8700
# 296      8652
# 403      8623
#         ...
# 115         1
# 111         1
# 567         1
# 99          1
# 1644        1
# Name: Distance, Length: 1419, dtype: int64

# %%
# Distancia del vuelo más largo
airlines_newdf['Distance'].max()
# Out:
# 4962

# %%
# Recordatório de las columnas
airlines_newdf[0:1]
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0      1           3          4   2003.0        1955   2211.0        2225
#
#   UniqueCarrier  FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  \
# 0            WN        335  N712SW              128.0           150.0
#
#    AirTime  ArrDelay  DepDelay Origin Dest  Distance  Cancelled  \
# 0    116.0     -14.0       8.0    IAD  TPA       810          0
#
#   CancellationCode  Diverted  CarrierDelay  WeatherDelay  NASDelay  \
# 0                N         0           NaN           NaN       NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN

# %%
# Numero de vuelos cancelados (1 = si)
cancel_flights = airlines_newdf['Cancelled'].value_counts()
cancel_flights
# Out:
# 0    1936125
# 1        633
# Name: Cancelled, dtype: int64

# %%
# Proporción vuelos cancelados
total_flights = airlines_newdf.shape[0]
total_flights
propor = (cancel_flights/total_flights)
propor
# Out:
# 0    0.999673
# 1    0.000327
# Name: Cancelled, dtype: float64

# %%
# CancellationCode: reason for cancellation (A = carrier, B = weather, C = NAS, D = security)
cancel_codes = airlines_newdf['CancellationCode'].value_counts()
cancel_codes
# El codigo N está en las líneas de los vuelos que no fueron cancelados
# Out:
# N    1936125
# B        307
# A        246
# C         80
# Name: CancellationCode, dtype: int64

# %%
# Vuelos desviados
airlines_newdf['Diverted'].value_counts()
# Out:
# 0    1929004
# 1       7754
# Name: Diverted, dtype: int64

# %%
# Total de minutos de cada código de retraso
total_delays = airlines_df[['CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']].sum()
total_delays

# Fuente y más detalles en : https://aspmhelp.faa.gov/index/Types_of_Delay.html

# Carrier delay is within the control of the air carrier. 
# Late Arrival Delay: Arrival delay at an airport due to the late arrival of the same aircraft at a previous airport.
# NAS Delay: Delay that is within the control of the National Airspace System (NAS) may include: non-extreme weather conditions, airport operations, heavy traffic volume, air traffic control, etc.
# Security delay is caused by evacuation of a terminal or concourse, re-boarding of aircraft because of security breach, inoperative screening equipment and/or long lines in excess of 29 minutes at screening areas.
# Weather Delay is caused by extreme or hazardous weather conditions that are forecasted or manifest themselves on point of departure, enroute, or on point of arrival.
# Out:
# CarrierDelay         23926070.0
# WeatherDelay          4620160.0
# NASDelay             18739310.0
# SecurityDelay          112445.0
# LateAircraftDelay    31557038.0
# dtype: float64

# %% [markdown]
# #### Datos faltantes hay por columna

# %%
# Datos faltantes por columna:
missing_data_count = airlines_newdf.isnull().sum()
missing_data_count
# Out:
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   5
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# dtype: int64

# %%
# % de valores que faltan hay sobre el total de valores
import numpy as np
total_cells = np.product(c.shape)
total_missing = missing_data_count.sum()
total_missing/total_cells*100
# Out:
# 6.908499826871663

# %%
airlines_newdf.shape
# Out:
# (1936758, 26)

# %%
# Toal de líneas del DataFrame
total_rows = len(airlines_newdf.index)
total_rows
# Out:
# 1936758

# %%
# % de datos faltantes por columna
missing_percent = missing_data_count/total_rows*100
missing_percent
# Out:
# Month                 0.000000
# DayofMonth            0.000000
# DayOfWeek             0.000000
# DepTime               0.000000
# CRSDepTime            0.000000
# ArrTime               0.367108
# CRSArrTime            0.000000
# UniqueCarrier         0.000000
# FlightNum             0.000000
# TailNum               0.000258
# ActualElapsedTime     0.433043
# CRSElapsedTime        0.010223
# AirTime               0.433043
# ArrDelay              0.433043
# DepDelay              0.000000
# Origin                0.000000
# Dest                  0.000000
# Distance              0.000000
# Cancelled             0.000000
# CancellationCode      0.000000
# Diverted              0.000000
# CarrierDelay         35.588855
# WeatherDelay         35.588855
# NASDelay             35.588855
# SecurityDelay        35.588855
# LateAircraftDelay    35.588855
# dtype: float64

# %%
# Las colunmas 'CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay' tienen un percentual alto de valores faltantes

# %% [markdown]
# #### Columnas Nuevas

# %%
# Columna velocidad media del vuleo
avg_speed = (airlines_newdf['Distance']*1.6093)/(airlines_newdf['AirTime']/60)
avg_speed
# Out:
# 0          674.241207
# 1          692.141416
# 2          654.307500
# 3          645.810000
# 4          763.585103
#               ...
# 1936753    729.012900
# 1936754    595.441000
# 1936755    545.315262
# 1936756    578.263079
# 1936757    811.458577
# Length: 1936758, dtype: float64

# %%
# Adicionar columna
airlines_newdf['AverageSpeed'] = avg_speed
airlines_newdf
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0            1           3          4   2003.0        1955   2211.0
# 1            1           3          4    754.0         735   1002.0
# 2            1           3          4    628.0         620    804.0
# 3            1           3          4   1829.0        1755   1959.0
# 4            1           3          4   1940.0        1915   2121.0
# ...        ...         ...        ...      ...         ...      ...
# 1936753     12          13          6   1250.0        1220   1617.0
# 1936754     12          13          6    657.0         600    904.0
# 1936755     12          13          6   1007.0         847   1149.0
# 1936756     12          13          6   1251.0        1240   1446.0
# 1936757     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0              2225            WN        335  N712SW              128.0
# ...

# %%
reduced_airlinesdf = airlines_newdf.sample(frac=0.05)
sample_reduced = reduced_airlinesdf[reduced_airlinesdf.UniqueCarrier.isin(["MQ","UA","DL","XE","CO","US"])]
sns.violinplot(x=sample_reduced["UniqueCarrier"], y=sample_reduced["AverageSpeed"])
plt.show()

# %%
reduced_airlinesdf["UniqueCarrier"][:5]
# Out:
# 55578      OO
# 352431     AS
# 794691     UA
# 1292246    WN
# 1230810    AA
# Name: UniqueCarrier, dtype: object

# %%
# Adicionar columna para informar si el vuelo tuve retraso en la llegada.
delay_arrival = (airlines_newdf['ArrDelay'] > 0)
airlines_newdf.insert(14,'DelayArrival',delay_arrival)
airlines_newdf
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0            1           3          4   2003.0        1955   2211.0
# 1            1           3          4    754.0         735   1002.0
# 2            1           3          4    628.0         620    804.0
# 3            1           3          4   1829.0        1755   1959.0
# 4            1           3          4   1940.0        1915   2121.0
# ...        ...         ...        ...      ...         ...      ...
# 1936753     12          13          6   1250.0        1220   1617.0
# 1936754     12          13          6    657.0         600    904.0
# 1936755     12          13          6   1007.0         847   1149.0
# 1936756     12          13          6   1251.0        1240   1446.0
# 1936757     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0              2225            WN        335  N712SW              128.0
# ...

# %%
# Adicionar columna para informar si el vuelo tuve retraso en la llegada.
delay_dep = (airlines_newdf['DepDelay'] > 0)
airlines_newdf.insert(16,'DelayDeparture',delay_arrival)
airlines_newdf
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0            1           3          4   2003.0        1955   2211.0
# 1            1           3          4    754.0         735   1002.0
# 2            1           3          4    628.0         620    804.0
# 3            1           3          4   1829.0        1755   1959.0
# 4            1           3          4   1940.0        1915   2121.0
# ...        ...         ...        ...      ...         ...      ...
# 1936753     12          13          6   1250.0        1220   1617.0
# 1936754     12          13          6    657.0         600    904.0
# 1936755     12          13          6   1007.0         847   1149.0
# 1936756     12          13          6   1251.0        1240   1446.0
# 1936757     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0              2225            WN        335  N712SW              128.0
# ...

# %%
airlines_newdf['Distance'].max()
# Out:
# 4962

# %%
# Inserción de columna de vuelos de más de 3000 mi (Vuelos largos)
long_flight = (airlines_newdf['Distance'] > 3000)
airlines_newdf.insert(20,'LongFlight',long_flight)
delay_dep = (airlines_newdf['DepDelay'] > 0)
airlines_newdf.insert(16,'DelayDeparture',delay_arrival)
airlines_newdf
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0            1           3          4   2003.0        1955   2211.0
# 1            1           3          4    754.0         735   1002.0
# 2            1           3          4    628.0         620    804.0
# 3            1           3          4   1829.0        1755   1959.0
# 4            1           3          4   1940.0        1915   2121.0
# ...        ...         ...        ...      ...         ...      ...
# 1936753     12          13          6   1250.0        1220   1617.0
# 1936754     12          13          6    657.0         600    904.0
# 1936755     12          13          6   1007.0         847   1149.0
# 1936756     12          13          6   1251.0        1240   1446.0
# 1936757     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0              2225            WN        335  N712SW              128.0
# ...

# %%
# Total de vuelos largos (True)
airlines_newdf['LongFlight'].value_counts()
# Out:
# False    1933235
# True        3523
# Name: LongFlight, dtype: int64

# %% [markdown]
# #### Datos estadísticos adicionales

# %%
# 25 vuelos más largos:
airlines_newdf[long_flight][:25]
# Out:
#        Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 66587      1           1          2   1030.0        1010   1541.0        1522
# 66588      1           2          3   1037.0        1010   1535.0        1522
# 66589      1           3          4   1028.0        1010   1515.0        1522
# 66590      1           5          6   1129.0        1010   1700.0        1522
# 66591      1           6          7   1038.0        1010   1554.0        1522
# 66592      1           9          3   1148.0        1025   1704.0        1541
# 66593      1          12          6   1051.0        1020   1603.0        1536
# 66594      1          15          2   1148.0        1025   1631.0        1541
# 66595      1          19          6   1123.0        1020   1555.0        1536
# 66596      1          20          7   1107.0        1025   1554.0        1541
# 66597      1          30          3   1230.0        1025   1730.0        1541
# ...

# %%
# 20 aerolíneas con más retraso acumulado en 2008 (en minutos):
airlines = airlines_newdf.groupby('UniqueCarrier')
total_delays = airlines['ArrDelay'].agg(np.sum)
total_delays.nlargest(20)
# Out:
# UniqueCarrier
# WN    11319092.0
# AA     8889066.0
# UA     6733013.0
# MQ     6396704.0
# OO     5978936.0
# XE     5176042.0
# DL     4535644.0
# CO     4045932.0
# EV     3888131.0
# YV     3691461.0
# US     3571867.0
# NW     3462075.0
# FL     3100150.0
# B6     3025749.0
# OH     2675993.0
# 9E     2420468.0
# AS     1406735.0
# F9      788549.0
# HA      255613.0
# AQ       15814.0
# Name: ArrDelay, dtype: float64

# %%
# Gráfico de las 20 aerolíneas con más retraso acumulado en 2008 (en minutos):
total_delays.nlargest(20).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='UniqueCarrier'>

# %%
# 20 vuelos más atrasados:
c[delay_arrival].sort_values(by = 'ArrDelay', ascending = False)[:20]
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 322516       2           3          7   1117.0        1820   2256.0
# 686014       4          10          4    724.0        1417    858.0
# 839306       5           6          2      2.0        1530    254.0
# 1009553      6          20          5   2140.0        1710   2252.0
# 1881639     12          19          5   1602.0        1325   1921.0
# 1497823      9           1          1    906.0         714   1048.0
# 685437       4          27          7   1818.0        1633   1942.0
# 163379       1           5          6    800.0        1045   1452.0
# 1214839      7          16          3    820.0         702   1325.0
# 521096       3          21          5    705.0         615    811.0
# 1875741     12          26          5   1733.0        1745   1847.0
# 1885481     12          17          3   1048.0        1125   1748.0
# 685763       4          24          4    821.0         900   1313.0
# ...

# %%
# 20 vuelos más atrasados a causa del tiempo:
airlines_newdf.sort_values(by = 'WeatherDelay', ascending = False)[:20]
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1875741     12          26          5   1733.0        1745   1847.0
# 1885481     12          17          3   1048.0        1125   1748.0
# 1906664     12          17          3   1103.0        1430   1555.0
# 1901407     12          17          3    908.0        1355   1627.0
# 350073       2           4          1   1116.0        1500   1537.0
# 1906058     12          17          3   1018.0        1600   1721.0
# 1887360     12          30          2    911.0        1410   1251.0
# 1905241     12          17          3    832.0        1305   1523.0
# 348679       2          11          1   1240.0        1800   1513.0
# 340219       2           5          2    900.0        1510   1038.0
# 133877       1           6          7   1234.0        1905   1348.0
# 676451       4          11          5   1310.0        1835   1453.0
# 1499943      9          14          7    759.0        1523    923.0
# ...

# %%
airlines_newdf[:1]
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0      1           3          4   2003.0        1955   2211.0        2225
#
#   UniqueCarrier  FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  \
# 0            WN        335  N712SW              128.0           150.0
#
#    AirTime  ArrDelay  DelayArrival  DepDelay  DelayDeparture Origin Dest  \
# 0    116.0     -14.0         False       8.0           False    IAD  TPA
#
#    Distance  LongFlight  Cancelled CancellationCode  Diverted  CarrierDelay  \
# 0       810       False          0                N         0           NaN
#
#    WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  AverageSpeed
# 0           NaN       NaN            NaN                NaN    674.241207

# %% [markdown]
# ## Exercici 3

# %%
# - Exercici 3
# Exporta el data set net i amb les noves columnes a Excel.

# %%
# Antes de exportar, vamos a limpiar los datos
# Verificar si hay liíneas duplicadas
airlines_newdf.duplicated().sum()
# Out:
# 2

# %%
temp_df = airlines_newdf.append(airlines_newdf) # Duplicando DataFrame sin cambiar el original
temp_df.shape
# Out:
# (3873516, 30)

# %%
# Eliminar duplicadas
temp_df = temp_df.drop_duplicates()
temp_df.shape
# Out:
# (1936756, 30)

# %%
# Las líneas duplicadas fueron eliminadas en temp_df
# Una alternativa es utilizar temp_df.drop_duplicates(inplace=True)

# %%
# Localizar valores nulos
temp_df.isnull().sum()
# Out:
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   5
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DelayArrival              0
# DepDelay                  0
# DelayDeparture            0
# Origin                    0
# Dest                      0
# Distance                  0
# LongFlight                0
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# AverageSpeed           8387
# dtype: int64

# %%
# Eliminar lineas donde hay un % bajo de valores nulos en algunas columnas.
temp_df = temp_df.dropna(axis=0, subset=['ArrTime','TailNum','ActualElapsedTime','CRSElapsedTime','AirTime','ArrDelay'])
temp_df.isnull().sum()
# Out:
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                   0
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   0
# ActualElapsedTime         0
# CRSElapsedTime            0
# AirTime                   0
# ArrDelay                  0
# DelayArrival              0
# DepDelay                  0
# DelayDeparture            0
# Origin                    0
# Dest                      0
# Distance                  0
# LongFlight                0
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         680882
# WeatherDelay         680882
# NASDelay             680882
# SecurityDelay        680882
# LateAircraftDelay    680882
# AverageSpeed              0
# dtype: int64

# %%
# Hay muchos valores nulos en las colunas que restan (cerca de 35% de total) y las las columnas me interesan
# No voy a eliminar todas estas colunmas ni las líneas donde hay valores nulos porque son interesantes. 
# Entonces voy a sustituir los valores nulos por zero.
temp_df = temp_df.fillna(0)
temp_df.isnull().sum()
# Out:
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DelayArrival         0
# DepDelay             0
# DelayDeparture       0
# Origin               0
# Dest                 0
# Distance             0
# LongFlight           0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# AverageSpeed         0
# dtype: int64

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1928366 entries, 0 to 1936757
# Data columns (total 30 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Month              int64
#  1   DayofMonth         int64
#  2   DayOfWeek          int64
#  3   DepTime            float64
#  4   CRSDepTime         int64
#  5   ArrTime            float64
#  6   CRSArrTime         int64
#  7   UniqueCarrier      object
#  8   FlightNum          int64
#  9   TailNum            object
#  10  ActualElapsedTime  float64
#  11  CRSElapsedTime     float64
#  12  AirTime            float64
#  13  ArrDelay           float64
#  14  DelayArrival       bool
#  15  DepDelay           float64
#  16  DelayDeparture     bool
#  17  Origin             object
#  18  Dest               object
#  19  Distance           int64
#  20  LongFlight         bool
#  21  Cancelled          int64
#  22  CancellationCode   object
#  23  Diverted           int64
# ...

# %%
# Exportar el Data Set Limpio y con las nuevas colunmas a Excel:

# Primero defino el nombre del arquivo:
#file_name = 'FlightsDataEduardoBaffi.xlsx'

# Exportar a Excel:
temp_df.to_csv('flights_data_eduardobaffi.csv')
print('DataFrame exportado a CSV!')
# Out:
# DataFrame exportado a CSV!
